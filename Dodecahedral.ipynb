# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import NGraph as mg

# %%
lDodec = [(1,2), (1,10), (1,11), (2,3),(2,12), (3,4), (3,13), (4,5), (4,14),
		  (5,6), (5,15),(6,7), (6,16),(7,8), (7,17),(8,9),(8,18),(9,10),(9,19),
		  (10,20),(11,13),(11,19),(12,14),(12,20),(13,15),(14,16),(15,17),(16,18),
		  (17,19),(18,20)]
mgDodec = mg.NGraph(weight=None)
mgDodec.add_edges_from(lDodec)
nx.draw(mgDodec, with_labels=True, node_color='y')

# %%
lDesargues = [(1,2),(1,10),(1,11),(2,3),(2,12),(3,4),(3,13),(4,5),(4,14),(5,6),
			  (5,15),(6,7),(6,16),(7,8),(7,17),(8,9),(8,18),(9,10),(9,19),
			  (10,20),(11,14),(11,18),(12,15),(12,19),(13,16),(13,20),(14,17),
			  (15,18),(16,19),(17,20)]

mgDesarg = mg.NGraph(weight=None)
mgDesarg.add_edges_from(lDesargues)
nx.draw(mgDesarg, with_labels=True, node_color='c')

# %%
mats_do, avgweis_do, diam_do = mgDodec.buildNodeDistMatricesToK(k=2)
avgweis_do
# Out:
# [2.6315789473684212, 3.736842105263158]

# %%
mats_do[0][:5,:10]
# Out:
# array([[0., 3., 6., 6., 3., 1., 0., 0., 0., 0.],
#        [0., 3., 6., 6., 3., 1., 0., 0., 0., 0.],
#        [0., 3., 6., 6., 3., 1., 0., 0., 0., 0.],
#        [0., 3., 6., 6., 3., 1., 0., 0., 0., 0.],
#        [0., 3., 6., 6., 3., 1., 0., 0., 0., 0.]])

# %%
mats_do[1][:5,:10]
# Out:
# array([[ 0.,  0.,  0.,  6., 12.,  1.,  0.,  0.,  0.,  0.],
#        [ 0.,  0.,  0.,  6., 12.,  1.,  0.,  0.,  0.,  0.],
#        [ 0.,  0.,  0.,  6., 12.,  1.,  0.,  0.,  0.,  0.],
#        [ 0.,  0.,  0.,  6., 12.,  1.,  0.,  0.,  0.,  0.],
#        [ 0.,  0.,  0.,  6., 12.,  1.,  0.,  0.,  0.,  0.]])

# %%
mats_de, avgweis_de, diam_de = mgDesarg.buildNodeDistMatricesToK(k=2)
avgweis_de
# Out:
# [2.6315789473684212, 3.8947368421052633]

# %%
mats_de[0][:5,:10]
# Out:
# array([[0., 3., 6., 6., 3., 1., 0., 0., 0., 0.],
#        [0., 3., 6., 6., 3., 1., 0., 0., 0., 0.],
#        [0., 3., 6., 6., 3., 1., 0., 0., 0., 0.],
#        [0., 3., 6., 6., 3., 1., 0., 0., 0., 0.],
#        [0., 3., 6., 6., 3., 1., 0., 0., 0., 0.]])

# %%
mats_de[1][:5,:10]
# Out:
# array([[0., 0., 0., 6., 9., 4., 0., 0., 0., 0.],
#        [0., 0., 0., 6., 9., 4., 0., 0., 0., 0.],
#        [0., 0., 0., 6., 9., 4., 0., 0., 0., 0.],
#        [0., 0., 0., 6., 9., 4., 0., 0., 0., 0.],
#        [0., 0., 0., 6., 9., 4., 0., 0., 0., 0.]])

# %%
js_do = mgDodec.JensenShannonDiverg(2)
js_do
# Out:
# ([-0.0, -0.0], [-0.0, -0.0])

# %%
js2g = mgDodec.JensenShannon2Graphs(mgDesarg,1)
js2g
# Out:
# 0.0

# %%
mgDodec.RavettiDissimilarity(mgDesarg)
# Out:
# 0.0

# %%
mgDodec.RavettiDissimilarityModified(mgDesarg,k=2)
# Out:
# 0.012133008352982855

# %%
mgDodec.graphNumber(k=4)
# Out:
# array([0.29398622, 0.29183287, 0.31468292, 0.39762215])

# %%
mgDesarg.graphNumber(k=4)
# Out:
# array([0.29398622, 0.30958768, 0.31468292, 0.35864418])
